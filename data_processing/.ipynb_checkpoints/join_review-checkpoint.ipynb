# %%
# imports
import pickle
import pandas as pd

# path = data/raw/full_ingredients.pkl

# input = pickle.load(open(path, "rb"))

# %%
Dict = {
("recipeid", 10): {
    "qty": 10, "unit": "kg", "name": "carrot cake", "other": "aad", "input": "10 kg of carrot cake", "comment": "adsa"
},
("recipeid2", 11): {
    "qty": 3, "unit": "mg", "name": "apple", "other": "aead", "input": "3mg apple", "comment": "ada"
},
("recipeid3", 12): {
    "qty": 22, "unit": "lb", "name": "water bottle", "other": "d", "input": "22 lb water bottle", "comment": "ada"
}
}
print(Dict)
# Out:
# {('recipeid', 10): {'qty': 10, 'unit': 'kg', 'name': 'carrot cake', 'other': 'aad', 'input': '10 kg of carrot cake', 'comment': 'adsa'}, ('recipeid2', 11): {'qty': 3, 'unit': 'mg', 'name': 'apple', 'other': 'aead', 'input': '3mg apple', 'comment': 'ada'}, ('recipeid3', 12): {'qty': 22, 'unit': 'lb', 'name': 'water bottle', 'other': 'd', 'input': '22 lb water bottle', 'comment': 'ada'}}

# %%
dict_units = [];
for key, value in Dict.items():
    dict_units.append(value['unit'])
dict_units
# Out:
# ['kg', 'mg', 'lb']

# %%
dict_names = [];
for key, value in Dict.items():
    dict_names.append(value['name'])
dict_names
# Out:
# ['carrot cake', 'apple', 'water bottle']

# %%
ingredients = pd.read_excel('550ingredients.xlsx')
ingredients.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          78.30     1.62            2.87           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#       ...      Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 0     ...             7.0      51.368       21.021        3.043
# 1     ...             4.6      45.390       19.874        3.331
# 2     ...             8.6      61.924       28.732        3.694
# 3     ...             2.4      18.669        7.778        0.800
# 4     ...             2.5      18.764        8.598        0.784
#
#    Cholestrl_(mg)  GmWt_1                  GmWt_Desc1  GmWt_2  \
# 0           215.0    5.00  1 pat,  (1" sq, 1/3" high)    14.2
# 1           225.0    3.80  1 pat,  (1" sq, 1/3" high)     9.4
# 2           256.0   12.80                      1 tbsp   205.0
# 3            75.0   28.35                        1 oz    17.0
# 4            94.0  132.00                1 cup, diced   113.0
#
#         GmWt_Desc2  Refuse_Pct
# 0           1 tbsp         0.0
# 1           1 tbsp         0.0
# 2            1 cup         0.0
# 3     1 cubic inch         0.0
# 4  1 cup, shredded         0.0
#
# [5 rows x 53 columns]

# %%
# percentage of units that don't have matches, put the ones without matches into a separate file or output

# %%
ingr_unit1 = ingredients[["Shrt_Desc", "GmWt_Desc1"]]
ingr_unit2 = ingredients[["Shrt_Desc", "GmWt_Desc2"]]
ingr_unit1.columns =["ingredient", "AU"]
ingr_unit2.columns =["ingredient", "AU"]
ingr_unit = pd.concat([ingr_unit1, ingr_unit2])

ingr_unit['amount'], ingr_unit['unit'] = ingr_unit['AU'].str.split(' ', 1).str
ingr_unit['unit'], ingr_unit['misc'] = ingr_unit['unit'].str.split(',', 1).str

ingr_unit.head(10000)
# Out:
#                                              ingredient  \
# 0                                      BUTTER,WITH SALT
# 1                                BUTTER,WHIPPED,W/ SALT
# 2                                  BUTTER OIL,ANHYDROUS
# 3                                           CHEESE,BLUE
# 4                                          CHEESE,BRICK
# 5                                           CHEESE,BRIE
# 6                                      CHEESE,CAMEMBERT
# 7                                        CHEESE,CARAWAY
# 8                                        CHEESE,CHEDDAR
# 9                                       CHEESE,CHESHIRE
# 10                                         CHEESE,COLBY
# 11                  CHEESE,COTTAGE,CRMD,LRG OR SML CURD
# 12                          CHEESE,COTTAGE,CRMD,W/FRUIT
# 13     CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD
# 14                     CHEESE,COTTAGE,LOWFAT,2% MILKFAT
# 15                     CHEESE,COTTAGE,LOWFAT,1% MILKFAT
# 16                                         CHEESE,CREAM
# 17                                          CHEESE,EDAM
# 18                                          CHEESE,FETA
# 19                                       CHEESE,FONTINA
# 20                                       CHEESE,GJETOST
# 21                                         CHEESE,GOUDA
# 22                                       CHEESE,GRUYERE
# 23                                     CHEESE,LIMBURGER
# 24                                      CHEESE,MONTEREY
# 25                           CHEESE,MOZZARELLA,WHL MILK
# 26                  CHEESE,MOZZARELLA,WHL MILK,LO MOIST
# 27                     CHEESE,MOZZARELLA,PART SKIM MILK
# 28                 CHEESE,MOZZARELLA,LO MOIST,PART-SKIM
# 29                                      CHEESE,MUENSTER
# ...                                                 ...
# 1180  TURKEY,DRUMSTK,FROM WHL BIRD,MEAT ONLY,W/ ADDE...
# 1181  TURKEY,THIGH,FROM WHL BIRD,MEAT ONLY,W/ ADDED ...
# 1182  TURKEY,RTL PARTS,BREAST,MEAT & SKN,W/ ADDED SO...
# 1183  TURKEY,THIGH,FROM WHL BIRD,MEAT ONLY,W/ ADDED ...
# 1184  TURKEY,WING,FROM WHL BIRD,MEAT ONLY,W/ ADDED S...
# 1185  TURKEY,WING,FROM WHL BIRD,MEAT ONLY,W/ ADDED S...
# 1186             TURKEY,RTL PARTS,BREAST,MEAT & SKN,RAW
# 1187        TURKEY,RTL PARTS,BREAST,MEAT & SKN,CKD,RSTD
# 1188               TURKEY,RTL PARTS,WING,MEAT & SKN,RAW
# 1189          TURKEY,RTL PARTS,WING,MEAT & SKN,CKD,RSTD
# 1190            TURKEY,RTL PARTS,DRUMSTK,MEAT & SKN,RAW
# 1191       TURKEY,RTL PARTS,DRUMSTK,MEAT & SKN,CKD,RSTD
# 1192         TURKEY,DRUMSTK,FROM WHL BIRD,MEAT ONLY,RAW
# 1193        TURKEY,DRUMSTK,FROM WHL BIRD,MEAT ONLY,RSTD
# 1194           TURKEY,THIGH,FROM WHL BIRD,MEAT ONLY,RAW
# 1195          TURKEY,THIGH,FROM WHL BIRD,MEAT ONLY,RSTD
# 1196              TURKEY,RTL PARTS,THIGH,MEAT & SKN,RAW
# 1197         TURKEY,RTL PARTS,THIGH,MEAT & SKN,CKD,RSTD
# 1198  TURKEY,BACK,FROM WHL BIRD,MEAT & SKN,W/ ADDED ...
# 1199  TURKEY,BACK,FROM WHL BIRD,MEAT & SKN,W/ ADDED ...
# 1200  CHICkN,BROILR OR FRYRS,BRST,SKNLSS,BNLESS,MEAT...
# 1201  CHCKN,BROLR OR FRYRS,BRST,SKNLSS,BNLESS,MEAT O...
# 1202  CKN,BRLER OR FRYERS,BRST,SKNLS,BNLS,MT ONLY,W ...
# 1203  CKN,BRLER/FRYERS,BRST,SKNLS,BNLS,MT ONLY,W ADD...
# 1204                     SOUP,CRM OF ASPARAGUS,CND,COND
# 1205                           SOUP,BLACK BEAN,CND,COND
# 1206    CAMPBELL'S RED & WHITE,BEEFY MUSHROOM SOUP,COND
# 1207                         SOUP,BEAN W/ PORK,CND,COND
# 1208                 SOUP,BEAN W/ FRANKFURTERS,CND,COND
# 1209                    SOUP,BEAN W/ HAM,CND,CHUNKY,RTS
#
#                               AU amount       unit                  misc
# 0     1 pat,  (1" sq, 1/3" high)      1        pat    (1" sq, 1/3" high)
# 1     1 pat,  (1" sq, 1/3" high)      1        pat    (1" sq, 1/3" high)
# 2                         1 tbsp      1       tbsp                   NaN
# 3                           1 oz      1         oz                   NaN
# 4                   1 cup, diced      1        cup                 diced
# 5                           1 oz      1         oz                   NaN
# 6                           1 oz      1         oz                   NaN
# 7                           1 oz      1         oz                   NaN
# 8                   1 cup, diced      1        cup                 diced
# 9                           1 oz      1         oz                   NaN
# 10                  1 cup, diced      1        cup                 diced
# 11                          4 oz      4         oz                   NaN
# 12                          4 oz      4         oz                   NaN
# 13          1 cup,  (not packed)      1        cup          (not packed)
# 14                          4 oz      4         oz                   NaN
# 15                          4 oz      4         oz                   NaN
# 16                        1 tbsp      1       tbsp                   NaN
# 17                          1 oz      1         oz                   NaN
# 18               1 cup, crumbled      1        cup              crumbled
# 19                  1 cup, diced      1        cup                 diced
# 20                          1 oz      1         oz                   NaN
# 21                          1 oz      1         oz                   NaN
# 22                          1 oz      1         oz                   NaN
# 23                         1 cup      1        cup                   NaN
# 24                  1 cup, diced      1        cup                 diced
# 25               1 cup, shredded      1        cup              shredded
# 26                          1 oz      1         oz                   NaN
# 27                          1 oz      1         oz                   NaN
# 28                  1 cup, diced      1        cup                 diced
# 29                  1 cup, diced      1        cup                 diced
# ...                          ...    ...        ...                   ...
# 1180                 1 drumstick      1  drumstick                   NaN
# 1181                     1 thigh      1      thigh                   NaN
# 1182                    1 breast      1     breast                   NaN
# 1183                     1 thigh      1      thigh                   NaN
# 1184                      1 wing      1       wing                   NaN
# 1185                      1 wing      1       wing                   NaN
# 1186                    1 breast      1     breast                   NaN
# 1187                    1 breast      1     breast                   NaN
# 1188                      1 wing      1       wing                   NaN
# 1189                      1 wing      1       wing                   NaN
# 1190                 1 drumstick      1  drumstick                   NaN
# 1191                 1 drumstick      1  drumstick                   NaN
# 1192                 1 drumstick      1  drumstick                   NaN
# 1193                 1 drumstick      1  drumstick                   NaN
# 1194                     1 thigh      1      thigh                   NaN
# 1195                     1 thigh      1      thigh                   NaN
# 1196                     1 thigh      1      thigh                   NaN
# 1197                     1 thigh      1      thigh                   NaN
# 1198                      1 back      1       back                   NaN
# 1199                      1 back      1       back                   NaN
# 1200                     1 piece      1      piece                   NaN
# 1201                     1 piece      1      piece                   NaN
# 1202                     1 piece      1      piece                   NaN
# 1203                     1 piece      1      piece                   NaN
# 1204          1 can,  (10.75 oz)      1        can            (10.75 oz)
# 1205  1 can,  (11 oz), undiluted      1        can    (11 oz), undiluted
# 1206                         NaN    NaN        NaN                   NaN
# 1207              1 can, 11.5 oz      1        can               11.5 oz
# 1208          1 can,  (11.25 oz)      1        can            (11.25 oz)
# 1209          1 can,  (19.25 oz)      1        can            (19.25 oz)
#
# [10000 rows x 5 columns]

# %%
# get unit set and add misc edge cases
unit_set = set(ingr_unit['unit'])
unit_set
# Out:
# {nan,
#  'Tbsp',
#  'shoot',
#  'pepper',
#  'quail',
#  'chicken',
#  'balsam-pear',
#  'tomato',
#  'bscuit',
#  'shell',
#  'chips',
#  'oz',
#  'medium',
#  'goldfish',
#  'pad',
#  'parsnip',
#  'unit',
#  'ring',
#  'mini bagel',
#  'pastry',
#  'beets',
#  'anisette sponge',
#  'crayfish',
#  'pie crust',
#  'envelope Alba',
#  'serving',
#  'milliliter',
#  'squab',
#  'sauce',
#  'container',
#  'fillet',
#  'ear',
#  'portion',
#  'pattie',
#  'piece',
#  'tortilla',
#  'yam',
#  'cruller',
#  'tablespoon',
#  'fruit',
#  'olive',
#  'biscuit',
#  'raw gizzard',
#  'skin',
#  'cocktail',
#  'eggs',
#  'set',
#  'flower',
#  'thigh',
#  'nuts',
#  'donut',
#  'teaspoon',
#  'neck',
#  'pouch',
#  'waxgourd',
#  'Wings',
#  'sheets',
#  'sausage',
#  'strips',
#  'item',
#  'cone',
#  'loaf',
#  'fries',
#  'sets',
#  'regular',
#  'rack',
#  'strip',
#  'fan fillet',
#  'kidney',
#  'stalks',
#  'seeds',
#  'grapes',
#  'egg roll',
#  'NLEA Serving',
#  'pomegranate',
#  'patty',
#  'envelope',
#  'cookies',
#  'plum',
#  'Arrowroot biscuit',
#  'frond',
#  'cupcake',
#  'leaves',
#  'link',
#  'wrap',
#  'kernel',
#  'bun',
#  'rib',
#  'can',
#  'box',
#  'bulb',
#  'goose',
#  'plant',
#  'petiole',
#  'saltines',
#  'dog',
#  'slice',
#  'back',
#  'filet',
#  'pie',
#  'radish',
#  'sheet',
#  'jar',
#  'Biscuits',
#  'sandwich',
#  'stem',
#  'burger',
#  'pod',
#  'duck',
#  'shank',
#  'quart',
#  'bunch',
#  'bag (7 oz)',
#  'corm',
#  'muffin',
#  'ml',
#  'eclair',
#  'lb',
#  'round piece',
#  'cup',
#  'mushroom',
#  'capon',
#  'inside drum',
#  'fish',
#  'rusk',
#  'nuggets',
#  'gizzard cooked',
#  'prunes',
#  'beet',
#  'steak',
#  'cakes',
#  'tsp',
#  'bars',
#  'apricot',
#  'hot dog',
#  'chop',
#  'spears',
#  'giblets',
#  'spray',
#  'egg',
#  'crackers',
#  'roll',
#  'Chiclets',
#  'flowerets',
#  'date',
#  'wing',
#  'leek',
#  'pint',
#  'Container',
#  'biscuits',
#  'crisps',
#  'small bagel',
#  'tablet',
#  'sprig',
#  'carton',
#  'ribs',
#  'breast',
#  'jumbo',
#  'gourd',
#  'bowl',
#  'onion',
#  'nut',
#  'half',
#  'stick',
#  'heart',
#  'full rump',
#  'prune',
#  'tube',
#  'envelope  Swiss Miss',
#  'taco',
#  'frankfurter',
#  'bagel',
#  'sprout',
#  'potato',
#  'lobster',
#  'bag',
#  'Burger',
#  'Cup',
#  'waffles',
#  'fig',
#  'eggplant',
#  'Serving',
#  'slices',
#  'small',
#  'entree',
#  'croissant',
#  'waterchestnuts',
#  'peanut',
#  'turkey',
#  'sprouts',
#  'g',
#  'toast',
#  'leg',
#  'bar',
#  'breadstick',
#  'links',
#  'medallion',
#  'individual',
#  'berries',
#  'inch',
#  'order',
#  'miniatures',
#  'cracker',
#  'waffle',
#  'square',
#  'roast',
#  'package',
#  "kid's meal",
#  'burrito',
#  'puffs',
#  'frank',
#  'spear',
#  'liver',
#  'Crispy Crowns',
#  'Cups',
#  'Roll',
#  'hotcakes',
#  'matzo',
#  'meatballs',
#  'gumdrops',
#  'wafers',
#  'bottle',
#  'packet',
#  'sprigs',
#  'rings',
#  'block',
#  'hot pocket',
#  'cutlet',
#  'grams',
#  'extra large',
#  'crab',
#  'quesadilla',
#  'beans',
#  'pancake',
#  'tablespoons',
#  'thick',
#  'cookie',
#  'cup(not packed)',
#  'pancakes',
#  'mini',
#  'pretzel',
#  'liver cooked',
#  'cube',
#  'stalk',
#  'mushrooms',
#  'crust',
#  'raw pr g',
#  'large',
#  'twists',
#  'cake',
#  'cherry',
#  'flat fillet',
#  'recipe',
#  'pat',
#  'Jigger',
#  'anchovy',
#  'pita',
#  'sapodilla',
#  'tbsp',
#  'drumstick',
#  'raw liver',
#  'chayote',
#  'EntrΘe',
#  'corndog',
#  'pieces',
#  'outside drum',
#  'melon',
#  'root',
#  'artichoke',
#  'Fudge Marshmallow',
#  'Patty',
#  'wafer',
#  'tamale',
#  'doughnut',
#  'cubic inch',
#  'fl oz',
#  'jigger',
#  'Figaroo',
#  'rolls',
#  'leaf',
#  'super colossal',
#  'pizza',
#  'cucumber',
#  'sundae',
#  'pods',
#  'donettes',
#  'wrapper',
#  'Bag',
#  'NLEA serving',
#  'head',
#  'tart',
#  'sausages',
#  'floweret',
#  'scoop',
#  'squash',
#  'bird',
#  'enchilada',
#  'junior',
#  'round waffle',
#  'sweetpotato',
#  'each',
#  'grape',
#  'Potato',
#  'broadbean',
#  'brownie',
#  'glass'}
